# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\aashi\\Documents\\dropout.csv.csv")

# %%
df.head()
#this dataset focuses upon the dropout rate across all states in India based upon the schooling stages,
#more specefically for boys and girls seperately and the total as well.
# Out:
#          State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 0   A & N Islands  2012-13         0.83          0.51          0.68
# 1   A & N Islands  2013-14         1.35          1.06          1.21
# 2   A & N Islands  2014-15         0.47          0.55          0.51
# 3  Andhra Pradesh  2012-13          3.3          3.05          3.18
# 4  Andhra Pradesh  2013-14         4.31          4.39          4.35
#
#   Upper Primary_Boys Upper Primary_Girls Upper Primary_Total Secondary _Boys  \
# 0     Uppe_r_Primary                1.09                1.23            5.57
# 1                 NR                1.54                0.51            8.36
# 2               1.44                1.95                1.69           11.47
# 3               3.21                3.51                3.36           12.21
# 4               3.46                4.12                3.78           11.95
#
#   Secondary _Girls Secondary _Total HrSecondary_Boys HrSecondary_Girls  \
# 0             5.55             5.56            17.66             10.15
# 1             5.98              7.2            18.94              12.2
# 2             8.16             9.87            21.05             12.21
# 3            13.25            12.72             2.66                NR
# 4            13.37            12.65            12.65             10.85
#
#   HrSecondary_Total
# 0             14.14
# 1             15.87
# 2             16.93
# 3              0.35
# 4             11.79

# %%
df.tail()
# Out:
#         State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 105  West Bengal  2013-14         3.44          2.37          2.91
# 106  West Bengal  2014-15         2.13          0.79          1.47
# 107    All India  2012-13         4.68          4.66          4.67
# 108    All India  2013-14         4.53          4.14          4.34
# 109    All India  2014-15         4.36          3.88          4.13
#
#     Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# 105               5.63                 3.1                4.31
# 106               5.84                2.88                 4.3
# 107                2.3                4.01                3.13
# 108               3.09                4.49                3.77
# 109               3.49                 4.6                4.03
#
#     Secondary _Boys Secondary _Girls Secondary _Total HrSecondary_Boys  \
# 105           16.73            19.77            18.34             8.03
# 106           16.33            19.06             17.8             8.18
# 107           14.54            14.54            14.54               NR
# 108           17.93            17.79            17.86             1.48
# 109           17.21            16.88            17.06             0.25
#
#     HrSecondary_Girls HrSecondary_Total
# 105              7.76               7.9
# 106              8.04              8.11
# 107                NR                NR
# 108              1.61              1.54
# 109                NR                NR

# %%
df.isnull()
# Out:
#      State_UT   year  Primary_Boys  Primary_Girls  Primary_Total  \
# 0       False  False         False          False          False
# 1       False  False         False          False          False
# 2       False  False         False          False          False
# 3       False  False         False          False          False
# 4       False  False         False          False          False
# ..        ...    ...           ...            ...            ...
# 105     False  False         False          False          False
# 106     False  False         False          False          False
# 107     False  False         False          False          False
# 108     False  False         False          False          False
# 109     False  False         False          False          False
#
#      Upper Primary_Boys  Upper Primary_Girls  Upper Primary_Total  \
# 0                 False                False                False
# 1                 False                False                False
# 2                 False                False                False
# 3                 False                False                False
# 4                 False                False                False
# ..                  ...                  ...                  ...
# 105               False                False                False
# 106               False                False                False
# 107               False                False                False
# 108               False                False                False
# 109               False                False                False
#
#      Secondary _Boys  Secondary _Girls  Secondary _Total  HrSecondary_Boys  \
# 0              False             False             False             False
# 1              False             False             False             False
# 2              False             False             False             False
# 3              False             False             False             False
# 4              False             False             False             False
# ..               ...               ...               ...               ...
# 105            False             False             False             False
# 106            False             False             False             False
# 107            False             False             False             False
# 108            False             False             False             False
# 109            False             False             False             False
#
#      HrSecondary_Girls  HrSecondary_Total
# 0                False              False
# 1                False              False
# 2                False              False
# 3                False              False
# 4                False              False
# ..                 ...                ...
# 105              False              False
# 106              False              False
# 107              False              False
# 108              False              False
# 109              False              False
#
# [110 rows x 14 columns]

# %%
df.describe()
# Out:
#        State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# count       110      110          110           110           110
# unique       40        3           93            87            87
# top       Bihar  2014-15           NR            NR            NR
# freq          3       37           15            15            17
#
#        Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# count                 110                 110                 110
# unique                 91                  97                  96
# top                    NR                  NR                  NR
# freq                   16                   8                   9
#
#        Secondary _Boys Secondary _Girls Secondary _Total HrSecondary_Boys  \
# count              110              110              110              110
# unique             106              107              106               81
# top                 NR               NR               NR               NR
# freq                 4                4                4               28
#
#        HrSecondary_Girls HrSecondary_Total
# count                110               110
# unique                76                78
# top                   NR                NR
# freq                  34                31

# %%
df['State_UT'].unique()
# Out:
# array(['A & N Islands', 'Andhra Pradesh', 'Arunachal  Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra & Nagar Haveli', 'Daman & Diu', 'Delhi',
#        'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Lakshadweep',
#        'Madhya  Pradesh', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil  Nadu', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal', 'All India'], dtype=object)

# %%
df.dtypes
# Out:
# State_UT               object
# year                   object
# Primary_Boys           object
# Primary_Girls          object
# Primary_Total          object
# Upper Primary_Boys     object
# Upper Primary_Girls    object
# Upper Primary_Total    object
# Secondary _Boys        object
# Secondary _Girls       object
# Secondary _Total       object
# HrSecondary_Boys       object
# HrSecondary_Girls      object
# HrSecondary_Total      object
# dtype: object

# %%
df = df[df['State_UT']=='Goa']

# %%
df.head()
# Out:
#    State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 30      Goa  2012-13           NR          0.26            NR
# 31      Goa  2013-14         0.08          0.33           0.2
# 32      Goa  2014-15         0.63          0.84          0.73
#
#    Upper Primary_Boys Upper Primary_Girls Upper Primary_Total Secondary _Boys  \
# 30                 NR                  NR                  NR            9.49
# 31                 NR                  NR                  NR           11.68
# 32                 NR                0.21                0.07           14.15
#
#    Secondary _Girls Secondary _Total HrSecondary_Boys HrSecondary_Girls  \
# 30             6.26             7.96            16.01               5.8
# 31             7.19             9.58            18.21              8.38
# 32             7.68            11.15            18.27              9.39
#
#    HrSecondary_Total
# 30             11.26
# 31             13.36
# 32             13.91

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 30 to 32
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State_UT           3 non-null      object
#  1   year               3 non-null      object
#  2   Secondary _Total   3 non-null      object
#  3   HrSecondary_Total  3 non-null      object
# dtypes: object(4)
# memory usage: 120.0+ bytes

# %%
df = df[df['State_UT']=='Goa']

# %%
df.head()
# Out:
#    State_UT     year Secondary _Total HrSecondary_Total
# 30      Goa  2012-13             7.96             11.26
# 31      Goa  2013-14             9.58             13.36
# 32      Goa  2014-15            11.15             13.91

# %%
df=pd.read_csv("C:\\Users\\aashi\\Documents\\dropout.csv.csv")

# %%
df = df[df['State_UT']=='Goa']

# %%
df.head()
# Out:
#    State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 30      Goa  2012-13           NR          0.26            NR
# 31      Goa  2013-14         0.08          0.33           0.2
# 32      Goa  2014-15         0.63          0.84          0.73
#
#    Upper Primary_Boys Upper Primary_Girls Upper Primary_Total Secondary _Boys  \
# 30                 NR                  NR                  NR            9.49
# 31                 NR                  NR                  NR           11.68
# 32                 NR                0.21                0.07           14.15
#
#    Secondary _Girls Secondary _Total HrSecondary_Boys HrSecondary_Girls  \
# 30             6.26             7.96            16.01               5.8
# 31             7.19             9.58            18.21              8.38
# 32             7.68            11.15            18.27              9.39
#
#    HrSecondary_Total
# 30             11.26
# 31             13.36
# 32             13.91

# %%
df=df.replace('NR',0)
df=df.replace('@',0)

# %%
df.head()
# Out:
#    State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 30      Goa  2012-13            0          0.26             0
# 31      Goa  2013-14         0.08          0.33           0.2
# 32      Goa  2014-15         0.63          0.84          0.73
#
#     Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# 30                   0                   0                   0
# 31                   0                   0                   0
# 32                   0                0.21                0.07
#
#    Secondary _Boys Secondary _Girls Secondary _Total HrSecondary_Boys  \
# 30            9.49             6.26             7.96            16.01
# 31           11.68             7.19             9.58            18.21
# 32           14.15             7.68            11.15            18.27
#
#    HrSecondary_Girls HrSecondary_Total
# 30               5.8             11.26
# 31              8.38             13.36
# 32              9.39             13.91

# %%
primary_boys=df['Primary_Total'].values.astype(np.float32)

# %%
df.dtypes
# Out:
# State_UT               object
# year                   object
# Primary_Boys           object
# Primary_Girls          object
# Primary_Total          object
# Upper Primary_Boys      int64
# Upper Primary_Girls    object
# Upper Primary_Total    object
# Secondary _Boys        object
# Secondary _Girls       object
# Secondary _Total       object
# HrSecondary_Boys       object
# HrSecondary_Girls      object
# HrSecondary_Total      object
# dtype: object

# %%
df=pd.read_csv("C:\\Users\\aashi\\Documents\\dropout.csv.csv")

# %%
df.head()
# Out:
#          State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 0   A & N Islands  2012-13         0.83          0.51          0.68
# 1   A & N Islands  2013-14         1.35          1.06          1.21
# 2   A & N Islands  2014-15         0.47          0.55          0.51
# 3  Andhra Pradesh  2012-13          3.3          3.05          3.18
# 4  Andhra Pradesh  2013-14         4.31          4.39          4.35
#
#   Upper Primary_Boys Upper Primary_Girls Upper Primary_Total Secondary _Boys  \
# 0     Uppe_r_Primary                1.09                1.23            5.57
# 1                 NR                1.54                0.51            8.36
# 2               1.44                1.95                1.69           11.47
# 3               3.21                3.51                3.36           12.21
# 4               3.46                4.12                3.78           11.95
#
#   Secondary _Girls Secondary _Total HrSecondary_Boys HrSecondary_Girls  \
# 0             5.55             5.56            17.66             10.15
# 1             5.98              7.2            18.94              12.2
# 2             8.16             9.87            21.05             12.21
# 3            13.25            12.72             2.66                NR
# 4            13.37            12.65            12.65             10.85
#
#   HrSecondary_Total
# 0             14.14
# 1             15.87
# 2             16.93
# 3              0.35
# 4             11.79

# %%
df=df.replace('NR',0)
df=df.replace('@',0)
df=df.replace('Uppe_r_Primary',0)
#replacing the null values with 0 to make the whole data set into numeric values

# %%
df.head()
# Out:
#          State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 0   A & N Islands  2012-13         0.83          0.51          0.68
# 1   A & N Islands  2013-14         1.35          1.06          1.21
# 2   A & N Islands  2014-15         0.47          0.55          0.51
# 3  Andhra Pradesh  2012-13          3.3          3.05          3.18
# 4  Andhra Pradesh  2013-14         4.31          4.39          4.35
#
#   Upper Primary_Boys Upper Primary_Girls Upper Primary_Total Secondary _Boys  \
# 0                  0                1.09                1.23            5.57
# 1                  0                1.54                0.51            8.36
# 2               1.44                1.95                1.69           11.47
# 3               3.21                3.51                3.36           12.21
# 4               3.46                4.12                3.78           11.95
#
#   Secondary _Girls Secondary _Total HrSecondary_Boys HrSecondary_Girls  \
# 0             5.55             5.56            17.66             10.15
# 1             5.98              7.2            18.94              12.2
# 2             8.16             9.87            21.05             12.21
# 3            13.25            12.72             2.66                 0
# 4            13.37            12.65            12.65             10.85
#
#   HrSecondary_Total
# 0             14.14
# 1             15.87
# 2             16.93
# 3              0.35
# 4             11.79

# %%
df.dtypes
# Out:
# State_UT               object
# year                   object
# Primary_Boys           object
# Primary_Girls          object
# Primary_Total          object
# Upper Primary_Boys     object
# Upper Primary_Girls    object
# Upper Primary_Total    object
# Secondary _Boys        object
# Secondary _Girls       object
# Secondary _Total       object
# HrSecondary_Boys       object
# HrSecondary_Girls      object
# HrSecondary_Total      object
# dtype: object

# %%
df["Primary_Boys"] = df["Primary_Boys"].astype(float).astype(int)
df["Primary_Girls"] = df["Primary_Girls"].astype(float).astype(int)
df["Primary_Total"] = df["Primary_Total"].astype(float).astype(int)
df["Upper Primary_Boys"] = df["Upper Primary_Boys"].astype(float).astype(int)
df["Upper Primary_Girls"] = df["Upper Primary_Girls"].astype(float).astype(int)
df["Upper Primary_Total"] = df["Upper Primary_Total"].astype(float).astype(int)
df["Secondary _Boys"] = df["Secondary _Boys"].astype(float).astype(int)
df["Secondary _Girls"] = df["Secondary _Girls"].astype(float).astype(int)
df["Secondary _Total"] = df["Secondary _Total"].astype(float).astype(int)
df["HrSecondary_Boys"] = df["HrSecondary_Boys"].astype(float).astype(int)
df["HrSecondary_Girls"] = df["HrSecondary_Girls"].astype(float).astype(int)
df["HrSecondary_Total"] = df["HrSecondary_Total"].astype(float).astype(int)

#converting float values to numeric for making the graphs

# %%
df.dtypes
# Out:
# State_UT               object
# year                   object
# Primary_Boys            int32
# Primary_Girls           int32
# Primary_Total           int32
# Upper Primary_Boys      int32
# Upper Primary_Girls     int32
# Upper Primary_Total     int32
# Secondary _Boys         int32
# Secondary _Girls        int32
# Secondary _Total        int32
# HrSecondary_Boys        int32
# HrSecondary_Girls       int32
# HrSecondary_Total       int32
# dtype: object

# %%
_=sns.barplot(x='Primary_Boys', y='Primary_Girls', data=df)
#this represents that on an average, as many girls dropout as many do boys at Primary School level

# %%
df.shape
# Out:
# (110, 14)

# %%
sns.pairplot(df)

# %%
import altair as alt

# %%
alt.Chart(df).mark_circle().encode(
x='Primary_Boys:Q',
y='Primary_Total:Q',
color='State_UT:N',
).interactive()
#there is a positive correlation between the two
# Out:
# alt.Chart(...)

# %%
x=df

# %%
df.iloc[0:3]
#a function to see individual state data
# Out:
#         State_UT     year  Primary_Boys  Primary_Girls  Primary_Total  \
# 0  A & N Islands  2012-13             0              0              0
# 1  A & N Islands  2013-14             1              1              1
# 2  A & N Islands  2014-15             0              0              0
#
#    Upper Primary_Boys  Upper Primary_Girls  Upper Primary_Total  \
# 0                   0                    1                    1
# 1                   0                    1                    0
# 2                   1                    1                    1
#
#    Secondary _Boys  Secondary _Girls  Secondary _Total  HrSecondary_Boys  \
# 0                5                 5                 5                17
# 1                8                 5                 7                18
# 2               11                 8                 9                21
#
#    HrSecondary_Girls  HrSecondary_Total
# 0                 10                 14
# 1                 12                 15
# 2                 12                 16

# %%
sns.boxplot(x='year', y='Upper Primary_Total', data=df)
#this represents year wise data w.r.t each school level
#here, the median value for all three years falls between 2.5-5.
# Out:
# <AxesSubplot:xlabel='year', ylabel='Upper Primary_Total'>

# %%
sns.boxplot(x='year', y='Primary_Total', data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Primary_Total'>

# %%
sns.boxplot(x='year', y='Secondary _Total', data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Secondary _Total'>

# %%
sns.boxplot(x='year', y='HrSecondary_Total', data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='HrSecondary_Total'>

# %%
dropout= pd.crosstab(df.year, df.State_UT)

# %%
dropout
#an year wise tabulation w.r.t each state
# Out:
# State_UT  A & N Islands  All India  Andhra Pradesh  Arunachal  Pradesh  \
# year
# 2012-13               1          1               1                   0
# 2013-14               1          1               1                   1
# 2014-15               1          1               1                   0
#
# State_UT  Arunachal Pradesh  Assam  Bihar  Chandigarh  Chhattisgarh  \
# year
# 2012-13                   1      1      1           1             1
# 2013-14                   0      1      1           1             1
# 2014-15                   1      1      1           1             1
#
# State_UT  Dadra & Nagar Haveli  ...  Punjab  Rajasthan  Sikkim  Tamil  Nadu  \
# year                            ...
# 2012-13                      1  ...       1          1       1            1
# 2013-14                      1  ...       1          1       1            0
# 2014-15                      1  ...       1          1       1            0
#
# State_UT  Tamil Nadu  Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# year
# 2012-13            0          0        1              1            1
# 2013-14            1          1        1              1            1
# 2014-15            1          1        1              1            1
#
# State_UT  West Bengal
# year
# 2012-13             1
# 2013-14             1
# 2014-15             1
#
# [3 rows x 40 columns]

# %%
sns.heatmap(dropout)
#heat map of the same which represents higher drop out rates in most states and lower in Tripura in 2012-13 which increased in 2014-15
# Out:
# <AxesSubplot:xlabel='State_UT', ylabel='year'>

# %%
df['Primary_Total'].mean()
#mean drop out rate of Primary school stage in total
# Out:
# 3.772727272727273

# %%
df['HrSecondary_Total'].mean()
#mean drop out rate of Higher Secondary school stage in total
# Out:
# 5.609090909090909

# %%
df['Secondary _Total'].mean()
#mean drop out rate of Secondary school stage in total
#the highest so far. Most children drop out from Secondary school.
# Out:
# 16.28181818181818

# %%
sns.set_style('whitegrid')
_=sns.lineplot(data=df, x='year', y= 'HrSecondary_Total', estimator= np.mean, hue='State_UT')
#This represents that in 2014-15, children in Higher secondary in state of Chhattisgrah dropped out the most and the numbers declined for Odisha.
