# %%
#importing all the necessary libraries to perform different functions
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading the file 
stu=pd.read_csv("C:\\Users\\singh\\OneDrive\\Documents\\15-StudentsPerformance.csv")

# %%
stu
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#command to identify the data types of the columns
stu.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
#command to identify the number of rows and columns
stu.shape
# Out:
# (1000, 8)

# %%
#to list the last 10 data entries
stu.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
#to list the last 10 data entries
stu.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
#type of dataset
type(stu)
# Out:
# pandas.core.frame.DataFrame

# %%
#to access the 3rd column
stu.columns[3]
# Out:
# 'lunch'

# %%
stu[['gender','math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
_=sns.pairplot(stu, hue="gender")

# %%
stu['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
stu['test preparation course'].unique()
# Out:
# array(['none', 'completed'], dtype=object)

# %%
stu['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
stu.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#identifying the null values in the 
stu.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
#Graphical representation of number of female and male students
stu['gender'].value_counts(normalize=True)
stu['gender'].value_counts(dropna=False).plot.bar()
plt.title('No. of Females and Males Students')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
#graphical presentation of number of member in each group
stu['race/ethnicity'].value_counts(normalize = True)
stu['race/ethnicity'].value_counts(dropna = False).plot.bar(color = 'red')
plt.title('Comparison of various groups')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
stu['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
# visualizing the differnt parental education levels

stu['parental level of education'].value_counts(normalize = True)
stu['parental level of education'].value_counts(dropna = False).plot.bar(color='green')
plt.title('Comparison of Parental Education')
plt.xlabel('Degree')
plt.ylabel('count')
plt.show()

# %%
stu['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
stu['lunch'].value_counts(normalize = True)
stu['lunch'].value_counts(dropna = False).plot.bar(color = 'orange')
plt.title('different types of lunch')
plt.xlabel('types of lunch')
plt.ylabel('count')
plt.show()

# %%
stu['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
sns.boxplot(y='math score',x='lunch', data=stu, hue='gender')
# Out:
# <AxesSubplot:xlabel='lunch', ylabel='math score'>

# %%
# visualizing maths score

stu['math score'].value_counts(normalize = True)
stu['math score'].value_counts(dropna = False).plot.bar(figsize = (18, 10))
plt.title('Comparison of math scores')
plt.xlabel('score')
plt.ylabel('count')
plt.show()

# %%
stu['math score'].value_counts()
# Out:
# 65    36
# 62    35
# 69    32
# 59    32
# 61    27
#       ..
# 24     1
# 26     1
# 28     1
# 33     1
# 0      1
# Name: math score, Length: 81, dtype: int64

# %%
# visualizing reading score score

stu['reading score'].value_counts(normalize = True)
stu['reading score'].value_counts(dropna = False).plot.bar(figsize = (18, 10), color = 'purple')
plt.title('Comparison of reading scores')
plt.xlabel('score')
plt.ylabel('count')
plt.show()

# %%
for item in stu.columns[-3:]:
    sns.boxplot(x=stu["test preparation course"], y=stu[item])
    plt.title(item+" vs pre test", loc="left")
    plt.show()

# %%
stu['writing score'].value_counts(normalize = True)
stu['writing score'].value_counts(dropna = False).plot.bar(figsize = (18, 10), color = 'Green')
plt.title('Comparison of writing scores')
plt.xlabel('score')
plt.ylabel('count')
plt.show()

# %%
for item in stu.columns[-3:]:
    sns.boxplot(x=stu["lunch"], y=stu[item])
    plt.title(item+" vs lunch", loc="left")
    plt.show()

# %%
# comparison of race/ethnicity and test preparation course
sns.countplot(x = 'race/ethnicity', data = stu,  hue = 'test preparation course', palette = 'bright')
plt.show()

# %%
# comparison of race/ethnicity and parental level of education

x = pd.crosstab(stu['race/ethnicity'], stu['parental level of education'])
x.div(x.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = 'True', figsize = (7, 4) )
# Out:
# <AxesSubplot:xlabel='race/ethnicity'>

# %%
# comparison of parental degree and test course

sns.countplot(x = 'parental level of education', data = stu, hue = 'test preparation course')
plt.show()

# %%
# gender vs race/etnicity 

x = pd.crosstab(stu['gender'], stu['race/ethnicity'])
x.div(x.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = True, figsize = (4, 4))
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
stu1=stu.select_dtypes(include=['int64','float64'])

# %%
stu1
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
pd.get_dummies('gender')
# Out:
#    gender
# 0       1

# %%
stu.gender=stu.gender.map({'male':0,'female':1})

# %%
stu
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0         1        group B           bachelor's degree      standard
# 1         1        group C                some college      standard
# 2         1        group B             master's degree      standard
# 3         0        group A          associate's degree  free/reduced
# 4         0        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995       1        group E             master's degree      standard
# 996       0        group C                 high school  free/reduced
# 997       1        group C                 high school  free/reduced
# 998       1        group D                some college      standard
# 999       1        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
stu1
# Out:
#      gender  math score  reading score  writing score
# 0         1          72             72             74
# 1         1          69             90             88
# 2         1          90             95             93
# 3         0          47             57             44
# 4         0          76             78             75
# ..      ...         ...            ...            ...
# 995       1          88             99             95
# 996       0          62             55             55
# 997       1          59             71             65
# 998       1          68             78             77
# 999       1          77             86             86
#
# [1000 rows x 4 columns]

# %%
plt.figure(figsize=(10,8))
pd.plotting.parallel_coordinates(stu1,class_column='gender',color=('red','blue'),)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import StandardScaler # to standardise the data

# %%
ss=StandardScaler()

# %%
ss.fit(stu1)
# Out:
# StandardScaler()

# %%
Z = ss.transform(stu1)

# %%
df1=pd.DataFrame(Z, columns=stu1.columns)

# %%
df1.head()
# Out:
#      gender  math score  reading score  writing score
# 0  0.964625    0.390024       0.193999       0.391492
# 1  0.964625    0.192076       1.427476       1.313269
# 2  0.964625    1.577711       1.770109       1.642475
# 3 -1.036672   -1.259543      -0.833899      -1.583744
# 4 -1.036672    0.653954       0.605158       0.457333

# %%
pd.plotting.parallel_coordinates(df1,class_column='gender',color=('red','blue'))
# Out:
# <AxesSubplot:>

# %%
_=pd.plotting.radviz(df1,class_column='gender',color=('red','green'))

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-152-43bef06448fc> in <module>
# ----> 1 import altair as alt
#
# ModuleNotFoundError: No module named 'altair'
